# %%
# Ensure this notebook kernel has torch available
import sys
print('Python executable:', sys.executable)

import importlib.util
if importlib.util.find_spec('torch') is None:
    print('torch not found in this kernel, installing now...')
    # %pip install torch numpy
else:
    print('torch already installed in this kernel')

import torch
print('torch version:', torch.__version__)
print('cuda available:', torch.cuda.is_available())
print('device:', torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
# Out:
# Python executable: d:\Anaconda\envs\ml-env\python.exe
# torch already installed in this kernel
# torch version: 2.12.1+cpu
# cuda available: False
# device: cpu

# %%
import torch

print('torch version:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
print('Current device:', torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('\nNote: This machine has an AMD GPU, and Windows does not support PyTorch CUDA/AMD ROCm with AMD graphics.')
print('For AMD GPU acceleration, use ROCm on Linux or run on CPU here.')
# Out:
# torch version: 2.12.1+cpu
# CUDA available: False
# Current device: cpu
#
# Note: This machine has an AMD GPU, and Windows does not support PyTorch CUDA/AMD ROCm with AMD graphics.
# For AMD GPU acceleration, use ROCm on Linux or run on CPU here.

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#       3 print(torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset
from transformers import GPT2Tokenizer
import math
import os
from tqdm import tqdm
import copy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'
